# %% [markdown]
# <a href="https://colab.research.google.com/github/yuhith10/gitdemo1/blob/main/Copy_of_lecture12_dataviz3_liveclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Agenda
#
# 1. Subplots
# 2. Multivariate Data Visualization
# - CCN
# - CNN
# - NNN
#
# 3. Joint plot
# 4. Pairplot
# 5. Correlation Heatmap

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !gdown https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166 -O vgsales.csv
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166
# To: /content/vgsales.csv
# 100% 2.04M/2.04M [00:00<00:00, 28.6MB/s]

# %%
data = pd.read_csv('vgsales.csv')
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %% [markdown]
# ## Subplots

# %%
plt.figure(figsize = (8,4))
sns.boxplot(x='EU_Sales', data = data)
# Out:
# <Axes: xlabel='EU_Sales'>

# %%
plt.figure(figsize = (8,5))




plt.subplot(2,3,3)
sns.boxplot(x='JP_Sales', data = data)

plt.subplot(2,3,5)
sns.boxplot(x='JP_Sales', data = data)


plt.subplot(2,6,4)
sns.boxplot(x='Global_Sales', data = data)


plt.subplot(2,6,6)
sns.boxplot(x='Global_Sales', data = data)

plt.subplot(2,6,7)
sns.boxplot(x='Global_Sales', data = data)

plt.subplot(2,6,1)
sns.boxplot(x='Global_Sales', data = data)

plt.subplot(2,6,2)
sns.boxplot(x='Global_Sales', data = data)


plt.subplot(2,3,1)
sns.boxplot(x='EU_Sales', data = data)



plt.subplot(3,5,3)
sns.boxplot(x='EU_Sales', data = data)
# Out:
# <ipython-input-15-c0856fc5cbb9>:17: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,6,6)
# <ipython-input-15-c0856fc5cbb9>:30: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,3,1)
# <ipython-input-15-c0856fc5cbb9>:35: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,5,3)
# <Axes: xlabel='EU_Sales'>

# %%
plt.figure(figsize = (8,5))


plt.subplot(2,3,1)
sns.boxplot(x='JP_Sales', data = data)

plt.subplot(2,3,2)
sns.boxplot(x='JP_Sales', data = data)

plt.subplot(2,3,3)
sns.boxplot(x='JP_Sales', data = data)

plt.subplot(2,3,4)
sns.boxplot(x='JP_Sales', data = data)

plt.subplot(2,3,5)
sns.boxplot(x='JP_Sales', data = data)

plt.subplot(2,3,6)
sns.boxplot(x='JP_Sales', data = data)
# Out:
# <Axes: xlabel='JP_Sales'>

# %% [markdown]
# ## Multivariate Data Visualization

# %%
# Num and Categorical

# Measure and Dimension (Tableau Terminology)

# %%
# 3+ Variable

# %%
top3_pub = data['Publisher'].value_counts().index[:3]
top3_gen = data['Genre'].value_counts().index[:3]
top3_plat = data['Platform'].value_counts().index[:3]
top3_data = data.loc[(data["Publisher"].isin(top3_pub)) & (data["Platform"].isin(top3_plat)) & (data['Genre'].isin(top3_gen))]
top3_data
# Out:
#         Rank                                               Name Platform  \
# 2      14279                  .hack: Sekai no Mukou ni + Versus      PS3
# 13      2742                                      [Prototype 2]      PS3
# 16      1604                                        [Prototype]      PS3
# 19      1741                             007: Quantum of Solace      PS3
# 21      4501                             007: Quantum of Solace      PS2
# ...      ...                                                ...      ...
# 16438  14938  Yes! Precure 5 Go Go Zenin Shu Go! Dream Festival       DS
# 16479  10979                              Young Justice: Legacy      PS3
# 16601  11802                         ZhuZhu Pets: Quest for Zhu       DS
# 16636   9196                           Zoobles! Spring to Life!       DS
# 16640   9816                                               Zubo       DS
#
#          Year   Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ###  NNC: Num-Num-Cat

# %%
plt.figure(figsize=(6,5))
sns.scatterplot(x='NA_Sales', y='EU_Sales',hue='Publisher',data=top3_data)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('NA Sales',fontsize=15)
plt.ylabel('EU Sales',fontsize=15)
plt.title('NA vs EU, per Publisher', fontsize=15)
plt.show()

# %% [markdown]
# # CCN (Cat-Cat-Num)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='Publisher',y='Global_Sales', hue = "Genre",data=top3_data)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Global Sales', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Global Sales for each Publisher, Genre wise', fontsize=15)
plt.show()

# %% [markdown]
# ## NNN - (Num - Num - Num)

# %%
x = "NA_Sales"
y = "JP_Sales"


sns.lineplot(x=x, y=y, data=top3_data)
# Out:
# <Axes: xlabel='NA_Sales', ylabel='JP_Sales'>

# %%
sns.scatterplot(x=x, y=y, data=top3_data)
# Out:
# <Axes: xlabel='NA_Sales', ylabel='JP_Sales'>

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x='NA_Sales', y='JP_Sales', size='Rank', sizes=(1, 200), data=data)
plt.xlabel('NA_Sales',fontsize=10)
plt.ylabel('JP Sales', fontsize=10)
plt.title('NA vs JP Sales, based on ranking of games', fontsize=15)
plt.show()

# %%
data["Rank"].sort_values()
# Out:
# 15934        1
# 13448        2
# 7895         3
# 15936        4
# 10583        5
#          ...
# 16067    16596
# 8201     16597
# 11974    16598
# 7051     16599
# 12934    16600
# Name: Rank, Length: 16652, dtype: int64

# %%
data[(data['NA_Sales'] > 6) & (data['JP_Sales'] < 6)][["Rank", "Name","NA_Sales"]].sort_values(by="Rank")
# Out:
#        Rank                           Name  NA_Sales
# 3722     10                      Duck Hunt  8.293241
# 9865     11                     Nintendogs  7.204972
# 15927    15                   Wii Fit Plus  7.207175
# 6940     16             Kinect Adventures!  7.706048
# 5268     17             Grand Theft Auto V  6.947338
# ...     ...                            ...       ...
# 4798    279                        Frogger  6.332366
# 7698    280                Madden NFL 2003  6.211941
# 5529    282                      Half-Life  6.393766
# 13070   297                    Star Fox 64  6.022451
# 674     374  Assassin's Creed: Brotherhood  6.043804
#
# [144 rows x 3 columns]

# %%
plt.figure(figsize = (8,5))
plt.subplot(2,3,4)
sns.boxplot(x='EU_Sales', data = data)

plt.subplot(2,3,5)
sns.boxplot(x='EU_Sales', data = data)

plt.subplot(2,3,6)
sns.boxplot(x='EU_Sales', data = data)
# Out:
# <Axes: xlabel='EU_Sales'>

# %% [markdown]
# ## Joint Plot

# %%
sns.jointplot(x='NA_Sales', y='EU_Sales', kind='hex', data=top3_data)
plt.show()

# %% [markdown]
# scatter | hex | hist | reg

# %%
sns.jointplot(x='NA_Sales', y='EU_Sales', kind='scatter', data=top3_data)
plt.show()

# %%
sns.jointplot(x='NA_Sales', y='EU_Sales', kind='hist', data=top3_data)
plt.show()

# %%
sns.jointplot(x='NA_Sales', y='EU_Sales', kind='reg', data=top3_data)
plt.show()

# %%
sns.jointplot(x='NA_Sales', y='EU_Sales', data=top3_data, hue='Genre')
plt.show()

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(data=top3_data, hue='Genre')
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
top3_data.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-c78d7a78d920> in <cell line: 1>()
# ----> 1 top3_data.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10702         cols = data.columns
#   10703         idx = cols.copy()
# > 10704         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10705
#   10706         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1887         if dtype is not None:
#    1888             dtype = np.dtype(dtype)
# -> 1889         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890         if result.dtype is not dtype:
#    1891             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
top3_data[['Rank','Year','NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].corr()
# Out:
#                   Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank          1.000000  0.328705 -0.873726 -0.735711  0.115459    -0.857567
# Year          0.328705  1.000000 -0.354256 -0.178026  0.055864    -0.239876
# NA_Sales     -0.873726 -0.354256  1.000000  0.617483 -0.233315     0.794353
# EU_Sales     -0.735711 -0.178026  0.617483  1.000000 -0.208249     0.771105
# JP_Sales      0.115459  0.055864 -0.233315 -0.208249  1.000000    -0.355825
# Other_Sales  -0.857567 -0.239876  0.794353  0.771105 -0.355825     1.000000
# Global_Sales -0.911721 -0.280351  0.856300  0.864147 -0.014193     0.878816
#
#               Global_Sales
# Rank             -0.911721
# Year             -0.280351
# NA_Sales          0.856300
# EU_Sales          0.864147
# JP_Sales         -0.014193
# Other_Sales       0.878816
# Global_Sales      1.000000

# %% [markdown]
# This is a correlation Matrix

# %%
# Correaltion ranges from -1 to 1

# %%
sns.heatmap(top3_data[['Rank','Year','NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].corr(),
            cmap= "inferno",
            annot=True)
plt.show()

# %%
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 
# ...

# %% [markdown]
# ## Quiz 1
#
# We are analyzing the results of the Olympics, and want to find the count of gold, silver, and bronze medals won by each country. Which will be the best suited plot for this?
#
# Ans: Side-by-side/Dodged bar chart

# %% [markdown]
# ## Quiz 2
#
# Suppose in a 2x3 subplot (2 rows 3 columns), we want to create a plot to span across the first row. What would be the right code for this?

# %%
plt.figure(figsize = (8,5))

plt.subplot(1,2,1)
sns.boxplot(x='EU_Sales', data = data)

# plt.subplot(2,3,4)
# sns.boxplot(x='EU_Sales', data = data)
# Out:
# <Axes: xlabel='EU_Sales'>

# %% [markdown]
# # DAV-1:
#
# # 1) Pandas(masking, iloc vs loc, creating dataframe, group by and agg, pivot/melt, slicing, stacking, splitting, apply),
# #    Numpy(Broadcasting, slicing, ele wise operation, vectorization)
# #    Viz (Given this question what type of plot tio use. Is it a UVA, BVA or MVA. How to read a box plot, when should i use a lineplot vs scatterplot)
#
#
# # Time your problem solving ability
